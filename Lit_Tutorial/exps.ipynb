# %%
import math
import matplotlib.pyplot as plt
import torch

from Activations import act_fn_by_name, get_viz

# %%
num_rows = math.ceil(len(act_fn_by_name)/2.)

fig, ax = plt.subplots(num_rows, 2)
x = torch.linspace(-5, 5, 1000)
act_fn_list = [act_fn() for act_fn in act_fn_by_name.values()]

for i, act_fn in enumerate(act_fn_list):
    get_viz(act_fn, x, ax[divmod(i,2)])
